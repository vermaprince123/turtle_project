# %%
from turtle import *
screensize(4000,4000)
Screen().bgcolor("black")
Screen().title("First Project - Prince Verma")
speed(20)
shape("turtle")


color('red', "cyan")
begin_fill()
while True:
    forward(200)
    left(90)
    if abs(pos()) < 1:
        break

        
        
while True:
    backward(200)
    right(90)
    if abs(pos()) < 1:
        break
end_fill()







color("red", "cyan")
begin_fill()
while True:
    forward(200)
    right(90)
    if abs(pos()) < 1:
        break

        
        
while True:
    backward(200)
    left(90)
    if abs(pos()) < 1:
        break        
end_fill()




color("red", "yellow")
begin_fill()
while True:
    backward(200)
    right(170)
    if abs(pos()) < 1:
        break        


while True:
    forward(200)
    left(170)
    if abs(pos()) < 1:
        break         

end_fill()
done()
